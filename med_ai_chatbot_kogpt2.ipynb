# %%
# !python data_processing.py

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -r requirments.txt

# %%
# !pip install transformers

# %%
# !pip install pytorch-lightning==1.9.0

# %%
# !python train.py

# %%
# !python predict.py
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT2Tokenizer'.
# The class this function is called from is 'PreTrainedTokenizerFast'.
# user > 안녕하세요 선생님 제가 손에 화상입었는데 어느 진료과를 가야될까요
# 요
# Chatbot > 저희는 진료과를 통해 자세한 진단을 위해 몇 가지 질문을 드릴 수 있을까요
# user > Chatbot > 요씨  제가 생각하기에는 치과 의사에게 직접 검진을 받아야 할 것 같습니다  의사는 상태를 확인하고 적절한 치료를 제시할 수 있을 겁니다
# user > 무슨 과죠 ?
# Chatbot > 그렇다면  통증을 완화하기 위해 어떤 조치를 취하셨나요
# user > Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/KoGPT2-chatbot/HealthCare-Chatbot/predict.py", line 31, in <module>
#     q = input("user > ").strip()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/KoGPT2-chatbot/HealthCare-Chatbot/predict.py", line 29, in <module>
#     with torch.no_grad():
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/grad_mode.py", line 83, in __exit__
#     torch.set_grad_enabled(self.prev)
#   File "/usr/local/lib/python3.10/dist-packages/torch/autograd/grad_mode.py", line 182, in __init__
#     def __init__(self, mode: bool) -> None:
# KeyboardInterrupt

# %%
cd drive/MyDrive/Colab Notebooks/KoGPT2-chatbot/HealthCare-Chatbot
# Out:
# /content/drive/MyDrive/Colab Notebooks/KoGPT2-chatbot/HealthCare-Chatbot

# %%
ls
# Out:
# data_processing.py           medical_conversation.gsheet  README.md         train.py
# med_ai_chatbot_kogpt2.ipynb  medical_conversation.json    requirements.txt
# medical_conversation.csv     predict.py                   saved_models/
